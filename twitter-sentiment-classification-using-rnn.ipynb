# %%
# !pip install contractions

# %% [markdown]
# should not - shouldn't these are contractions

# %%
from concurrent.futures import ThreadPoolExecutor
from multiprocessing import cpu_count
import contractions
import re
from nltk import word_tokenize
import nltk
from nltk.corpus import stopwords
from spacy.lang.en.stop_words import STOP_WORDS
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn

# %% [markdown]
# concurrent is for parallel programming,
#  re is regular expressions,
#  stopwords are i,am, at, and, is, than, etc,
#  spacy contains many languages,
#  pos = part of speech,

# %%
import pandas as pd
from keras.layers import TextVectorization
import numpy as np
from keras.layers import Input, Embedding, LSTM, GRU, Dense
from keras.models import Sequential
import pickle
import locale
import tensorflow as tf
import os

# %%
nltk.download("punkt")

# %% [markdown]
# punkt is a tokenizor ,
# tokenizor is a piece of algo. which tokenizes your code
# it will break the sentence into words , in programming words are tokens
# for eg. this is the first session on nlp --> ["this","is","the","first","session","on","nlp"] this is token it returns the sentence in form of list.

# %% [markdown]
# lemmatization is intelligent stemming . it tries to perform stemmimg of the word and look for the word
# for eg if the word is behaved if we do stemmimg of this word then it will become behav then  it will look into the english dictionary for the word and if doesn't find that word then it does not perform stemming it will look for the part of speech of every word and if the word is noun then it cannot be stemmed , noun cannot be stemmed it we do not assign the pos_tag to the word then the lemmatizer will consider it as noun.

# %%
nltk.download("stopwords")

# %%
nltk.download("averaged_perceptron_tagger")

# %%
nltk.download("averaged_perceptron_tagger")

# %%
nltk.download("wordnet")

# %%
cpu_count

# %%
data=pd.read_csv("/kaggle/input/sentiment140/training.1600000.processed.noemoticon.csv",encoding="latin-1",header=None)

# %% [markdown]
# Text Preprocessing
#
# Step 1 : Normalising the text(converting upper case into lower case)
#
# Step 2 : Expand the contractions inside text

# %% [markdown]
# regular expressions are pattern matching string in the string every symbol written has a meaning the re library scan the symbols

# %%
data.shape

# %%
data.head()

# %%
def normalise_tweet(tweet_text):
    return tweet_text_lower()
with ThreadPoolExecutor(max_workers=4) as pool:
    reduced_data["text"]=list(pool.map[expand_contarctions])

# %% [markdown]
# ?: this regular expression balances the precedence
